# %%
import os
print(os.path.exists(
    r"C:\Users\pc\Desktop\최인규\건들면사망\q&ai\models\qwen2-5.gguf"
))
# Out:
# True

# %%
import os
from pathlib import Path

print("CWD:", os.getcwd())
print("HERE:", Path(__file__).resolve().parent)
print("models exists:", Path("models").exists())
print("models list:", list(Path("models").glob("*")))
# Out:
# CWD: c:\Users\pc\Desktop\최인규\건들면사망\q&ai
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       2 from pathlib import Path
#       4 print("CWD:", os.getcwd())
# ----> 5 print("HERE:", Path(__file__).resolve().parent)
#       6 print("models exists:", Path("models").exists())
#       7 print("models list:", list(Path("models").glob("*")))
#
# NameError: name '__file__' is not defined
